# %%
# Import dependencies
import requests
import pandas as pd
from config import api_key
import json

# %% [markdown]
# # 1- Park Alerts

# %%
# Set the URL of the NPS Alerts API and set any required parameters
url = "https://developer.nps.gov/api/v1/alerts"
params = {
    "api_key": api_key
}

# %%
# Create empty list for alerts
alerts = []

# Retrieve alerts in batches of 50 using pagination
while True:
    response = requests.get(url, params=params)
    data = response.json()  
    alert_data = data['data']  
    alerts.extend(alert_data)
    
    if len(alerts) >= int(data['total']):
        break
    
    params['start'] = str(len(alerts))  # Set the start parameter to retrieve the next batch of alerts

# Create & preview Alerts DataFrame
alerts_df = pd.DataFrame(alerts)
alerts_df.head()
# Out:
#                                      id  \
# 0  A06A73AB-01EE-45ED-8B00-F9F230CF7D35
# 1  00A34521-182A-49D9-9AB0-1F7F7F8A54D4
# 2  6AB9D11C-8AE1-471A-BD28-51D5DEFEB133
# 3  460D3A8F-4374-47CF-8C93-2B89527ACD9D
# 4  9D988058-30B5-49A9-8553-B1983B8209E6
#
#                                                  url  \
# 0  https://forecast.weather.gov/MapClick.php?lon=...
# 1
# 2
# 3  https://www.nps.gov/bicy/learn/news/big-cypres...
# 4   https://www.nps.gov/glca/learn/news/20210720.htm
#
#                                                title parkCode  \
# 0          Road to Rim Village is Temporarily CLOSED     crla
# 1  High surf, rip currents, and heavy rainfall th...     viis
# 2  River Mountain Loop Trail Partial Closure - MM...     lake
# 3  Big Cypress National Preserve Issues Temporary...     bicy
# 4           Dangling Rope Marina Closed Indefinitely     rabr
#
#                                          description      category  \
# 0  The road from Park Headquarters to Rim Village...  Park Closure
# 1  From Wednesday April 5, 2023, and running thro...       Caution
# 2  The River Mountain Loop will be closed for res...  Park Closure
# 3  Big Cypress National Preserve has issued a tem...  Park Closure
# 4  Due to significant wind damage and low water c...   Information
#
#          lastIndexedDate
# 0  2023-04-05 14:42:20.0
# 1  2023-04-05 14:24:21.0
# 2  2023-04-05 14:05:11.0
# 3  2023-04-05 13:29:29.0
# 4  2023-04-05 13:13:13.0

# %%
# Retrieve column headers
alerts_df.columns
# Out:
# Index(['id', 'url', 'title', 'parkCode', 'description', 'category',
#        'lastIndexedDate'],
#       dtype='object')

# %% [markdown]
# # 2- Park

# %%
# Set the URL of the NPS Parks API and set any required parameters
url_parks = "https://developer.nps.gov/api/v1/parks"
params = {
    'api_key': api_key
}

# %%
# Create empty list for parks
parks = []

# Retrieve parks in batches of 50 using pagination
while True:
    response = requests.get(url_parks, params=params)
    data = response.json()
    park_data = data['data']
    parks.extend(park_data)
    
    if len(parks) >= int(data['total']):
        break
    
    params['start'] = str(len(parks))  # Set the start parameter to retrieve the next batch of parks

# Create & preview Parks DataFrame
parks_df = pd.DataFrame(parks)
parks_df.head()
# Out:
#                                      id                                 url  \
# 0  77E0D7F0-1942-494A-ACE2-9004D2BDC59E  https://www.nps.gov/abli/index.htm
# 1  6DA17C86-088E-4B4D-B862-7C1BD5CF236B  https://www.nps.gov/acad/index.htm
# 2  E4C7784E-66A0-4D44-87D0-3E072F5FEF43  https://www.nps.gov/adam/index.htm
# 3  1A47416F-DAA3-4137-9F30-14AF86B4E547  https://www.nps.gov/afam/index.htm
# 4  E6E1D22A-7A89-47F8-813C-B611059A8CF9  https://www.nps.gov/afbg/index.htm
#
#                                             fullName parkCode  \
# 0  Abraham Lincoln Birthplace National Historical...     abli
# 1                               Acadia National Park     acad
# 2                     Adams National Historical Park     adam
# 3                African American Civil War Memorial     afam
# 4            African Burial Ground National Monument     afbg
#
#                                          description     latitude  \
# 0  For over a century people from around the worl...   37.5858662
# 1  Acadia National Park protects the natural beau...    44.409286
# 2  From the sweet little farm at the foot of Penn...   42.2553961
# 3  Over 200,000 African-American soldiers and sai...      38.9166
# 4  African Burial Ground is the oldest and larges...  40.71452681
#
#       longitude                             latLong  \
# 0  -85.67330523   lat:37.5858662, long:-85.67330523
# 1    -68.247501      lat:44.409286, long:-68.247501
# 2  -71.01160356   lat:42.2553961, long:-71.01160356
# 3       -77.026           lat:38.9166, long:-77.026
# 4  -74.00447358  lat:40.71452681, long:-74.00447358
#
#                                           activities  \
# 0  [{'id': '13A57703-BB1A-41A2-94B8-53B692EB7238'...
# 1  [{'id': '09DF0950-D319-4557-A57E-04CD2F63FF42'...
# 2  [{'id': 'B33DC9B6-0B7D-4322-BAD7-A13A34C584A3'...
# 3  [{'id': 'B33DC9B6-0B7D-4322-BAD7-A13A34C584A3'...
# 4  [{'id': '09DF0950-D319-4557-A57E-04CD2F63FF42'...
#
#                                               topics  ...  \
# 0  [{'id': 'D10852A3-443C-4743-A5FA-6DD6D2A054B3'...  ...
# 1  [{'id': '00F3C3F9-2D67-4802-81AE-CCEA5D3BA370'...  ...
# 2  [{'id': 'F3883A66-A7CB-461B-868E-1B5932224B25'...  ...
# 3  [{'id': '28AEAE85-9DDA-45B6-981B-1CFCDCC61E14'...  ...
# 4  [{'id': '28AEAE85-9DDA-45B6-981B-1CFCDCC61E14'...  ...
#
#                                       entrancePasses fees  \
# 0                                                 []   []
# 1  [{'cost': '70.00', 'description': 'Valid for 1...   []
# 2                                                 []   []
# 3  [{'cost': '0.00', 'description': 'No Passes', ...   []
# 4  [{'cost': '0.00', 'description': 'There are no...   []
#
#                                       directionsInfo  \
# 0  The Birthplace Unit of the park is located app...
# 1  From Boston take I-95 north to Augusta, Maine,...
# 2  Traveling on U.S. Interstate 93, take exit 7 -...
# 3  The memorial is located at the corner of Vermo...
# 4  The African Burial Ground National Monument is...
#
#                                        directionsUrl  \
# 0  http://www.nps.gov/abli/planyourvisit/directio...
# 1  http://www.nps.gov/acad/planyourvisit/directio...
# 2  http://www.nps.gov/adam/planyourvisit/directio...
# 3  http://www.nps.gov/afam/planyourvisit/directio...
# 4  http://www.nps.gov/afbg/planyourvisit/directio...
#
#                                       operatingHours  \
# 0  [{'exceptions': [{'exceptionHours': {}, 'start...
# 1  [{'exceptions': [], 'description': 'Acadia Nat...
# 2  [{'exceptions': [], 'description': 'The histor...
# 3  [{'exceptions': [], 'description': 'The Africa...
# 4  [{'exceptions': [{'exceptionHours': {'monday':...
#
#                                            addresses  \
# 0  [{'postalCode': '42748', 'city': 'Hodgenville'...
# 1  [{'postalCode': '04609', 'city': 'Bar Harbor',...
# 2  [{'postalCode': '02169', 'city': 'Quincy', 'st...
# 3  [{'postalCode': '20001', 'city': 'Washington',...
# 4  [{'postalCode': '10007', 'city': 'New York', '...
#
#                                               images  \
# 0  [{'credit': 'NPS Photo', 'title': 'The Memoria...
# 1  [{'credit': 'NPS / Kristi Rugg', 'title': 'Aca...
# 2  [{'credit': 'NPS Photo', 'title': 'The John an...
# 3  [{'credit': 'NPS Photo', 'title': 'African Ame...
# 4  [{'credit': 'NPS Photo', 'title': 'African Bur...
#
#                                          weatherInfo  \
# 0  There are four distinct seasons in Central Ken...
# 1  Located on Mount Desert Island in Maine, Acadi...
# 2  Be prepared for hot, humid weather. The histor...
# 3  Washington DC gets to see all four seasons. Hu...
# 4  http://forecast.weather.gov/MapClick.php?CityN...
#
#                                   name               designation
# 0           Abraham Lincoln Birthplace  National Historical Park
# 1                               Acadia             National Park
# 2                                Adams  National Historical Park
# 3  African American Civil War Memorial
# 4                African Burial Ground         National Monument
#
# [5 rows x 23 columns]

# %%
# Retrieve column headers
parks_df.columns
# Out:
# Index(['id', 'url', 'fullName', 'parkCode', 'description', 'latitude',
#        'longitude', 'latLong', 'activities', 'topics', 'states', 'contacts',
#        'entranceFees', 'entrancePasses', 'fees', 'directionsInfo',
#        'directionsUrl', 'operatingHours', 'addresses', 'images', 'weatherInfo',
#        'name', 'designation'],
#       dtype='object')

# %% [markdown]
# # 3- Merge Park & Alert Data

# %%
# Slice Parks columns & preview DataFrame
park_col = parks_df.loc[:,['fullName', 'parkCode']]
park_col.head()
# Out:
#                                             fullName parkCode
# 0  Abraham Lincoln Birthplace National Historical...     abli
# 1                               Acadia National Park     acad
# 2                     Adams National Historical Park     adam
# 3                African American Civil War Memorial     afam
# 4            African Burial Ground National Monument     afbg

# %%
# Slice Alerts columns & preview DataFrame
alerts_col = alerts_df.loc[:,['title', 'parkCode', 'description', 'lastIndexedDate']]
alerts_col.head()
# Out:
#                                                title parkCode  \
# 0          Road to Rim Village is Temporarily CLOSED     crla
# 1  High surf, rip currents, and heavy rainfall th...     viis
# 2  River Mountain Loop Trail Partial Closure - MM...     lake
# 3  Big Cypress National Preserve Issues Temporary...     bicy
# 4           Dangling Rope Marina Closed Indefinitely     rabr
#
#                                          description        lastIndexedDate
# 0  The road from Park Headquarters to Rim Village...  2023-04-05 14:42:20.0
# 1  From Wednesday April 5, 2023, and running thro...  2023-04-05 14:24:21.0
# 2  The River Mountain Loop will be closed for res...  2023-04-05 14:05:11.0
# 3  Big Cypress National Preserve has issued a tem...  2023-04-05 13:29:29.0
# 4  Due to significant wind damage and low water c...  2023-04-05 13:13:13.0

# %%
# Merge Parks & Alerts and preview DataFrame
park_alert_merge = pd.merge(alerts_col, park_col, on=['parkCode'])
park_alert_merge.head()
# Out:
#                                                title parkCode  \
# 0          Road to Rim Village is Temporarily CLOSED     crla
# 1           Crater Lake National Park is a Snow Zone     crla
# 2    Steel Visitor Center is Closed for Construction     crla
# 3  Rim Drive and North Entrance Road Closed for t...     crla
# 4  High surf, rip currents, and heavy rainfall th...     viis
#
#                                          description        lastIndexedDate  \
# 0  The road from Park Headquarters to Rim Village...  2023-04-05 14:42:20.0
# 1  Roads are plowed, but icy and snow covered. Cr...  2022-12-23 16:38:22.0
# 2  The visitor center at park headquarters is cur...  2022-11-23 15:37:24.0
# 3  The park has closed Rim Drive, North Entrance ...  2022-11-09 16:56:15.0
# 4  From Wednesday April 5, 2023, and running thro...  2023-04-05 14:24:21.0
#
#                        fullName
# 0     Crater Lake National Park
# 1     Crater Lake National Park
# 2     Crater Lake National Park
# 3     Crater Lake National Park
# 4  Virgin Islands National Park

# %%
# Rename column headers and preivew DataFrame
park_alert_merge.rename(columns={'title': 'Alert', 'description': 'Description', 'lastIndexedDate': 'Date', 'fullName': 'Park Name'}, inplace=True)
park_alert_merge.head()
# Out:
#                                                Alert parkCode  \
# 0          Road to Rim Village is Temporarily CLOSED     crla
# 1           Crater Lake National Park is a Snow Zone     crla
# 2    Steel Visitor Center is Closed for Construction     crla
# 3  Rim Drive and North Entrance Road Closed for t...     crla
# 4  High surf, rip currents, and heavy rainfall th...     viis
#
#                                          Description                   Date  \
# 0  The road from Park Headquarters to Rim Village...  2023-04-05 14:42:20.0
# 1  Roads are plowed, but icy and snow covered. Cr...  2022-12-23 16:38:22.0
# 2  The visitor center at park headquarters is cur...  2022-11-23 15:37:24.0
# 3  The park has closed Rim Drive, North Entrance ...  2022-11-09 16:56:15.0
# 4  From Wednesday April 5, 2023, and running thro...  2023-04-05 14:24:21.0
#
#                       Park Name
# 0     Crater Lake National Park
# 1     Crater Lake National Park
# 2     Crater Lake National Park
# 3     Crater Lake National Park
# 4  Virgin Islands National Park

# %%
# Output DataFrame to CSV file
park_alert_merge.to_csv("statics/data/alerts_df.csv", index=False,encoding="utf-8")

# %% [markdown]
# # 3- Reformat Park Data

# %%
# Slice Parks data and preview DataFrame
parks_rev_df = parks_df.loc[:,['fullName', 'parkCode', 'description', 'directionsInfo', 'addresses']]
parks_rev_df.head()
# Out:
#                                             fullName parkCode  \
# 0  Abraham Lincoln Birthplace National Historical...     abli
# 1                               Acadia National Park     acad
# 2                     Adams National Historical Park     adam
# 3                African American Civil War Memorial     afam
# 4            African Burial Ground National Monument     afbg
#
#                                          description  \
# 0  For over a century people from around the worl...
# 1  Acadia National Park protects the natural beau...
# 2  From the sweet little farm at the foot of Penn...
# 3  Over 200,000 African-American soldiers and sai...
# 4  African Burial Ground is the oldest and larges...
#
#                                       directionsInfo  \
# 0  The Birthplace Unit of the park is located app...
# 1  From Boston take I-95 north to Augusta, Maine,...
# 2  Traveling on U.S. Interstate 93, take exit 7 -...
# 3  The memorial is located at the corner of Vermo...
# 4  The African Burial Ground National Monument is...
#
#                                            addresses
# 0  [{'postalCode': '42748', 'city': 'Hodgenville'...
# 1  [{'postalCode': '04609', 'city': 'Bar Harbor',...
# 2  [{'postalCode': '02169', 'city': 'Quincy', 'st...
# 3  [{'postalCode': '20001', 'city': 'Washington',...
# 4  [{'postalCode': '10007', 'city': 'New York', '...

# %%
# Slice address data
address = parks_rev_df.iloc[:,4]

# Create empty DataFrame for parsed address data
address_append = pd.DataFrame()

# Loop through rows, parse data and append to DataFrame
for i in range (0, len(address)):
    data = pd.DataFrame(list(address[i]))
    address_append = address_append.append(data)
# Out:
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# ...
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)
# C:\Users\walden\AppData\Local\Temp\ipykernel_31136\1258097279.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_append = address_append.append(data)

# %%
# Remove mailing addresses, concatenate address data and preview DataFrame
address_physical = address_append.loc[(address_append['type'] == 'Physical') | (address_append['postalCode'] == '04765')]
    # One park only has mailinng address - used that as physical address
address_physical = address_physical[['line1', 'line2', 'line3', 'city', 'stateCode', 'postalCode']]
address_physical['address'] = address_physical.agg(lambda cols: ', '.join(cols.dropna()), axis=1)
address_physical = address_physical[['address']]
address_physical.reset_index(drop=True, inplace=True)
address_physical
# Out:
#                                                address
# 0    2995 Lincoln Farm Road, , , Hodgenville, KY, 4...
# 1    25 Visitor Center Road, Hulls Cove Visitor Cen...
# 2              135 Adams Street, , , Quincy, MA, 02169
# 3    1925 Vermont Avenue Northwest, , , Washington,...
# 4    African Burial Ground National Monument, 290 B...
# ..                                                 ...
# 463  Yorktown Battlefield, 1000 Colonial Parkway, ,...
# 464        9039 Village Drive, , , Yosemite, CA, 95389
# 465          Off County Rd 20.5, , , Cortez, CO, 81321
# 466   101 Dunkel St, Suite 110, , Fairbanks, AK, 99701
# 467  Zion National Park, 1 Zion Park Blvd., , Sprin...
#
# [468 rows x 1 columns]

# %%
# Merge Parks and Address, rename column headers and preview DataFrame
parks_rev_df = pd.merge(parks_rev_df, address_physical, left_index=True, right_index=True)
parks_rev_df.drop(['addresses'], axis=1, inplace=True)
parks_rev_df.rename(columns={'fullName': 'Name', 
                             'description': 'Description', 
                             'directionsInfo''address': 'Directions', 
                             'address': 'Address'}, inplace=True)
parks_rev_df
# Out:
#                                                   Name parkCode  \
# 0    Abraham Lincoln Birthplace National Historical...     abli
# 1                                 Acadia National Park     acad
# 2                       Adams National Historical Park     adam
# 3                  African American Civil War Memorial     afam
# 4              African Burial Ground National Monument     afbg
# ..                                                 ...      ...
# 463  Yorktown Battlefield Part of Colonial National...     york
# 464                             Yosemite National Park     yose
# 465                      Yucca House National Monument     yuho
# 466           Yukon - Charley Rivers National Preserve     yuch
# 467                                 Zion National Park     zion
#
#                                            Description  \
# 0    For over a century people from around the worl...
# 1    Acadia National Park protects the natural beau...
# 2    From the sweet little farm at the foot of Penn...
# 3    Over 200,000 African-American soldiers and sai...
# 4    African Burial Ground is the oldest and larges...
# ..                                                 ...
# 463  Discover what it took for the United States to...
# 464  Not just a great valley, but a shrine to human...
# 465  Yucca House National Monument preserves a larg...
# 466  Located in Interior Alaska, Yukon-Charley Rive...
# 467  Follow the paths where native people and pione...
#
#                                         directionsInfo  \
# 0    The Birthplace Unit of the park is located app...
# 1    From Boston take I-95 north to Augusta, Maine,...
# 2    Traveling on U.S. Interstate 93, take exit 7 -...
# 3    The memorial is located at the corner of Vermo...
# 4    The African Burial Ground National Monument is...
# ..                                                 ...
# 463  For an internet map search or GPS, use the fol...
# 464  You can drive to Yosemite year-round and enter...
# 465  From Cortez, take Hwy. 491 south approximately...
# 466  Although there is no direct highway connection...
# 467  Zion National Park's main, south entrance and ...
#
#                                                Address
# 0    2995 Lincoln Farm Road, , , Hodgenville, KY, 4...
# 1    25 Visitor Center Road, Hulls Cove Visitor Cen...
# 2              135 Adams Street, , , Quincy, MA, 02169
# 3    1925 Vermont Avenue Northwest, , , Washington,...
# 4    African Burial Ground National Monument, 290 B...
# ..                                                 ...
# 463  Yorktown Battlefield, 1000 Colonial Parkway, ,...
# 464        9039 Village Drive, , , Yosemite, CA, 95389
# 465          Off County Rd 20.5, , , Cortez, CO, 81321
# 466   101 Dunkel St, Suite 110, , Fairbanks, AK, 99701
# 467  Zion National Park, 1 Zion Park Blvd., , Sprin...
#
# [468 rows x 5 columns]

# %%
# Export to CSV
parks_rev_df.to_csv("statics/data/parks_df.csv", index=False,encoding="utf-8")

# %% [markdown]
# # 2- Campground

# %%
# Set the URL of the NPS Parks API and set any required parameters
url_campgrounds = "https://developer.nps.gov/api/v1/campgrounds"
params = {
    'api_key': api_key
}

# %%
# Create empty list for campgrounds
campgrounds = []

# Retrieve parks in batches of 50 using pagination
while True:
    response = requests.get(url_campgrounds, params=params)
    data = response.json()
    campground_data = data['data']
    campgrounds.extend(campground_data)
    
    if len(campgrounds) >= int(data['total']):
        break
    
    params['start'] = str(len(campgrounds))  # Set the start parameter to retrieve the next batch of campgrounds

# Create & preview Alerts DataFrame
campgrounds_df = pd.DataFrame(campgrounds)
campgrounds_df.head()
# Out:
#                                      id  \
# 0  EA81BC45-C361-437F-89B8-5C89FB0D0F86
# 1  1241C56B-7003-4FDF-A449-29DA8BCB0A41
# 2  ABDC6E2A-9959-4A4C-9DB6-EEF66E7C95B8
# 3  4F9ED6A5-3ED1-443D-9E4C-859D7988F199
# 4  9FAE941D-D7E8-4F36-A28F-8556628242BA
#
#                                                  url                     name  \
# 0  https://www.nps.gov/amis/planyourvisit/277-nor...     277 North Campground
# 1                                                     Abrams Creek Campground
# 2  https://www.recreation.gov/camping/campgrounds...      Adirondack Shelters
# 3  https://www.nps.gov/bica/planyourvisit/afterba...      Afterbay Campground
# 4  https://www.nps.gov/ozar/planyourvisit/akers-c...   Akers Group Campground
#
#   parkCode                                        description  \
# 0     amis  277 North Campground is generally open year-ro...
# 1     grsm  Abrams Creek Campground - elevation 1,125 feet...
# 2     cato  Reservations Required. No Walk Ins. There are ...
# 3     bica  - Near Fort Smith, Montana - Open All Year! - ...
# 4     ozar  Group campsites, located at Akers Ferry. The c...
#
#              latitude            longitude  \
# 0  29.512373695509215  -100.90816633365614
# 1   35.61074664664336   -83.93318327404131
# 2   39.67775041640082   -77.48462720159597
# 3  45.315438210045016  -107.94165891102676
# 4       37.3764551871       -91.5615463252
#
#                                              latLong  \
# 0  {lat:29.512373695509215, lng:-100.90816633365614}
# 1    {lat:35.61074664664336, lng:-83.93318327404131}
# 2    {lat:39.67775041640082, lng:-77.48462720159597}
# 3  {lat:45.315438210045016, lng:-107.94165891102676}
# 4            {lat:37.3764551871, lng:-91.5615463252}
#
#                                     audioDescription isPassportStampLocation  \
# 0  277 North Campground is generally open year-ro...                       0
# 1  Mountain ranges and a pristine creek are the b...                       0
# 2  The Adirondack shelters are three-walled and r...                       0
# 3                                                                          0
# 4                                                                          0
#
#    ...                                     operatingHours  \
# 0  ...  [{'exceptions': [], 'description': '277 North ...
# 1  ...  [{'exceptions': [{'exceptionHours': {'wednesda...
# 2  ...  [{'exceptions': [], 'description': 'The Adiron...
# 3  ...  [{'exceptions': [], 'description': 'Open year ...
# 4  ...  [{'exceptions': [], 'description': 'Group camp...
#
#                                            addresses  \
# 0                                                 []
# 1  [{'postalCode': '37878', 'city': 'Tallassee', ...
# 2  [{'postalCode': '21788', 'city': 'Thurmont', '...
# 3  [{'postalCode': '59035', 'city': 'Fort Smith',...
# 4  [{'postalCode': '65466', 'city': 'Eminence', '...
#
#                                               images  \
# 0  [{'credit': 'NPS Photo', 'crops': [], 'title':...
# 1  [{'credit': 'NPS Photot', 'crops': [], 'title'...
# 2  [{'credit': 'NPS Photo', 'crops': [], 'title':...
# 3  [{'credit': 'NPS, Jen Prentiss', 'crops': [], ...
# 4  [{'credit': 'NPS', 'crops': [], 'title': 'Aker...
#
#                                      weatherOverview numberOfSitesReservable  \
# 0  The climate at Amistad is semi-arid in moistur...                       1
# 1  This campground is in the mountains and weathe...                      16
# 2  Summer (June-Aug) average temperature is betwe...                       2
# 3  For the most recent weather forecast please lo...                      22
# 4  Ozark National Scenic Riverways is located in ...                       4
#
#   numberOfSitesFirstComeFirstServe  \
# 0                               17
# 1                                0
# 2                                0
# 3                                0
# 4                                4
#
#                                            campsites  \
# 0  {'totalSites': '18', 'group': '1', 'horse': '0...
# 1  {'totalSites': '16', 'group': '0', 'horse': '0...
# 2  {'totalSites': '2', 'group': '0', 'horse': '0'...
# 3  {'totalSites': '22', 'group': '0', 'horse': '0...
# 4  {'totalSites': '4', 'group': '4', 'horse': '0'...
#
#                                        accessibility multimedia  \
# 0  {'wheelchairAccess': 'Limited. However, some s...         []
# 1  {'wheelchairAccess': 'Campground is not ADA ac...         []
# 2  {'wheelchairAccess': 'None', 'internetInfo': '...         []
# 3  {'wheelchairAccess': 'All sites are handicappe...         []
# 4  {'wheelchairAccess': 'No wheelchair access.', ...         []
#
#   lastIndexedDate
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 32 columns]

# %%
# Retrieve column headers
campgrounds_df.columns
# Out:
# Index(['id', 'url', 'name', 'parkCode', 'description', 'latitude', 'longitude',
#        'latLong', 'audioDescription', 'isPassportStampLocation',
#        'passportStampLocationDescription', 'passportStampImages',
#        'geometryPoiId', 'reservationInfo', 'reservationUrl', 'regulationsurl',
#        'regulationsOverview', 'amenities', 'contacts', 'fees',
#        'directionsOverview', 'directionsUrl', 'operatingHours', 'addresses',
#        'images', 'weatherOverview', 'numberOfSitesReservable',
#        'numberOfSitesFirstComeFirstServe', 'campsites', 'accessibility',
#        'multimedia', 'lastIndexedDate'],
#       dtype='object')

# %% [markdown]
# # Merge Parks, Alerts & Campgrounds into one DataFrame

# %%
# Slice only necessary columns
cleaned_alerts_df = alerts_df[['parkCode','title','category','description','url']]
cleaned_parks_df = parks_df[['fullName','parkCode','states','latitude','longitude', 'directionsInfo','operatingHours', 'addresses']]
cleaned_campgrounds_df = campgrounds_df[['parkCode','name','latitude','longitude']]

# %%
# Rename campground column headers and preview DataFrame
cleaned_campgrounds_df = cleaned_campgrounds_df.rename(columns={'latitude': 'lat_camp', 'longitude': 'lon_camp'})
cleaned_campgrounds_df.head()
# Out:
#   parkCode                     name            lat_camp             lon_camp
# 0     amis     277 North Campground  29.512373695509215  -100.90816633365614
# 1     grsm  Abrams Creek Campground   35.61074664664336   -83.93318327404131
# 2     cato      Adirondack Shelters   39.67775041640082   -77.48462720159597
# 3     bica      Afterbay Campground  45.315438210045016  -107.94165891102676
# 4     ozar   Akers Group Campground       37.3764551871       -91.5615463252

# %%
# Merge Alerts and Parks and retrieve DataFrame shape
merged_df = pd.merge(cleaned_alerts_df, cleaned_parks_df, on='parkCode', how='inner')
merged_df.shape
# Out:
# (762, 12)

# %%
# Preview DataFrame
merged_df.head()
# Out:
#   parkCode                                              title      category  \
# 0     crla          Road to Rim Village is Temporarily CLOSED  Park Closure
# 1     crla           Crater Lake National Park is a Snow Zone       Caution
# 2     crla    Steel Visitor Center is Closed for Construction   Information
# 3     crla  Rim Drive and North Entrance Road Closed for t...  Park Closure
# 4     viis  High surf, rip currents, and heavy rainfall th...       Caution
#
#                                          description  \
# 0  The road from Park Headquarters to Rim Village...
# 1  Roads are plowed, but icy and snow covered. Cr...
# 2  The visitor center at park headquarters is cur...
# 3  The park has closed Rim Drive, North Entrance ...
# 4  From Wednesday April 5, 2023, and running thro...
#
#                                                  url  \
# 0  https://forecast.weather.gov/MapClick.php?lon=...
# 1              https://tripcheck.com/Pages/Chain-Law
# 2  https://www.nps.gov/crla/planyourvisit/visitor...
# 3  https://www.nps.gov/crla/learn/news/winter-fee...
# 4
#
#                        fullName states     latitude     longitude  \
# 0     Crater Lake National Park     OR  42.94065854  -122.1338414
# 1     Crater Lake National Park     OR  42.94065854  -122.1338414
# 2     Crater Lake National Park     OR  42.94065854  -122.1338414
# 3     Crater Lake National Park     OR  42.94065854  -122.1338414
# 4  Virgin Islands National Park     VI  18.34279656  -64.74194451
#
#                                       directionsInfo  \
# 0  From the west (Medford) - Take Hwy 62 to the W...
# 1  From the west (Medford) - Take Hwy 62 to the W...
# 2  From the west (Medford) - Take Hwy 62 to the W...
# 3  From the west (Medford) - Take Hwy 62 to the W...
# 4  There are no airports on St. John so you must ...
#
#                                       operatingHours  \
# 0  [{'exceptions': [{'exceptionHours': {}, 'start...
# 1  [{'exceptions': [{'exceptionHours': {}, 'start...
# 2  [{'exceptions': [{'exceptionHours': {}, 'start...
# 3  [{'exceptions': [{'exceptionHours': {}, 'start...
# 4  [{'exceptions': [{'exceptionHours': {'wednesda...
#
#                                            addresses
# 0  [{'postalCode': '97604', 'city': 'Crater Lake'...
# 1  [{'postalCode': '97604', 'city': 'Crater Lake'...
# 2  [{'postalCode': '97604', 'city': 'Crater Lake'...
# 3  [{'postalCode': '97604', 'city': 'Crater Lake'...
# 4  [{'postalCode': '00830', 'city': 'St. John', '...

# %%
# Merge the merged and campground DataFrames and retrieve DataFrame shape
merged_df = pd.merge(merged_df, cleaned_campgrounds_df, on='parkCode', how='inner')
merged_df.shape
# Out:
# (2144, 15)

# %%
# Preview DataFrame
merged_df.head()
# Out:
#   parkCode                                            title      category  \
# 0     crla        Road to Rim Village is Temporarily CLOSED  Park Closure
# 1     crla        Road to Rim Village is Temporarily CLOSED  Park Closure
# 2     crla         Crater Lake National Park is a Snow Zone       Caution
# 3     crla         Crater Lake National Park is a Snow Zone       Caution
# 4     crla  Steel Visitor Center is Closed for Construction   Information
#
#                                          description  \
# 0  The road from Park Headquarters to Rim Village...
# 1  The road from Park Headquarters to Rim Village...
# 2  Roads are plowed, but icy and snow covered. Cr...
# 3  Roads are plowed, but icy and snow covered. Cr...
# 4  The visitor center at park headquarters is cur...
#
#                                                  url  \
# 0  https://forecast.weather.gov/MapClick.php?lon=...
# 1  https://forecast.weather.gov/MapClick.php?lon=...
# 2              https://tripcheck.com/Pages/Chain-Law
# 3              https://tripcheck.com/Pages/Chain-Law
# 4  https://www.nps.gov/crla/planyourvisit/visitor...
#
#                     fullName states     latitude     longitude  \
# 0  Crater Lake National Park     OR  42.94065854  -122.1338414
# 1  Crater Lake National Park     OR  42.94065854  -122.1338414
# 2  Crater Lake National Park     OR  42.94065854  -122.1338414
# 3  Crater Lake National Park     OR  42.94065854  -122.1338414
# 4  Crater Lake National Park     OR  42.94065854  -122.1338414
#
#                                       directionsInfo  \
# 0  From the west (Medford) - Take Hwy 62 to the W...
# 1  From the west (Medford) - Take Hwy 62 to the W...
# 2  From the west (Medford) - Take Hwy 62 to the W...
# 3  From the west (Medford) - Take Hwy 62 to the W...
# 4  From the west (Medford) - Take Hwy 62 to the W...
#
#                                       operatingHours  \
# 0  [{'exceptions': [{'exceptionHours': {}, 'start...
# 1  [{'exceptions': [{'exceptionHours': {}, 'start...
# 2  [{'exceptions': [{'exceptionHours': {}, 'start...
# 3  [{'exceptions': [{'exceptionHours': {}, 'start...
# 4  [{'exceptions': [{'exceptionHours': {}, 'start...
#
#                                            addresses  \
# 0  [{'postalCode': '97604', 'city': 'Crater Lake'...
# 1  [{'postalCode': '97604', 'city': 'Crater Lake'...
# 2  [{'postalCode': '97604', 'city': 'Crater Lake'...
# 3  [{'postalCode': '97604', 'city': 'Crater Lake'...
# 4  [{'postalCode': '97604', 'city': 'Crater Lake'...
#
#                                                 name           lat_camp  \
# 0  Lost Creek Campground, elevation 6,000 feet (1...      42.8797493937
# 1                                  Mazama Campground  42.86862146054785
# 2  Lost Creek Campground, elevation 6,000 feet (1...      42.8797493937
# 3                                  Mazama Campground  42.86862146054785
# 4  Lost Creek Campground, elevation 6,000 feet (1...      42.8797493937
#
#              lon_camp
# 0      -122.038711217
# 1  -122.1677826463598
# 2      -122.038711217
# 3  -122.1677826463598
# 4      -122.038711217

# %%
# Check for NA values
if merged_df.isna().any().any():
    print("There are NA values in the merged dataframe")
else:
    print("There are no NA values in the merged dataframe")
# Out:
# There are no NA values in the merged dataframe

# %%
# Retrieve column headers
merged_df.columns
# Out:
# Index(['parkCode', 'title', 'category', 'description', 'url', 'fullName',
#        'states', 'latitude', 'longitude', 'directionsInfo', 'operatingHours',
#        'addresses', 'name', 'lat_camp', 'lon_camp'],
#       dtype='object')

# %%
# Reorder columns
column_order = ['parkCode', 'fullName', 'states', 'latitude', 'longitude', 
                'directionsInfo', 'operatingHours',
                'title', 'category', 'description', 'url', 
                'addresses', 'name', 'lat_camp', 'lon_camp']
merged_df = merged_df[column_order]

# %%
# Preview DataFrame
merged_df.head()
# Out:
#   parkCode                   fullName states     latitude     longitude  \
# 0     crla  Crater Lake National Park     OR  42.94065854  -122.1338414
# 1     crla  Crater Lake National Park     OR  42.94065854  -122.1338414
# 2     crla  Crater Lake National Park     OR  42.94065854  -122.1338414
# 3     crla  Crater Lake National Park     OR  42.94065854  -122.1338414
# 4     crla  Crater Lake National Park     OR  42.94065854  -122.1338414
#
#                                       directionsInfo  \
# 0  From the west (Medford) - Take Hwy 62 to the W...
# 1  From the west (Medford) - Take Hwy 62 to the W...
# 2  From the west (Medford) - Take Hwy 62 to the W...
# 3  From the west (Medford) - Take Hwy 62 to the W...
# 4  From the west (Medford) - Take Hwy 62 to the W...
#
#                                       operatingHours  \
# 0  [{'exceptions': [{'exceptionHours': {}, 'start...
# 1  [{'exceptions': [{'exceptionHours': {}, 'start...
# 2  [{'exceptions': [{'exceptionHours': {}, 'start...
# 3  [{'exceptions': [{'exceptionHours': {}, 'start...
# 4  [{'exceptions': [{'exceptionHours': {}, 'start...
#
#                                              title      category  \
# 0        Road to Rim Village is Temporarily CLOSED  Park Closure
# 1        Road to Rim Village is Temporarily CLOSED  Park Closure
# 2         Crater Lake National Park is a Snow Zone       Caution
# 3         Crater Lake National Park is a Snow Zone       Caution
# 4  Steel Visitor Center is Closed for Construction   Information
#
#                                          description  \
# 0  The road from Park Headquarters to Rim Village...
# 1  The road from Park Headquarters to Rim Village...
# 2  Roads are plowed, but icy and snow covered. Cr...
# 3  Roads are plowed, but icy and snow covered. Cr...
# 4  The visitor center at park headquarters is cur...
#
#                                                  url  \
# 0  https://forecast.weather.gov/MapClick.php?lon=...
# 1  https://forecast.weather.gov/MapClick.php?lon=...
# 2              https://tripcheck.com/Pages/Chain-Law
# 3              https://tripcheck.com/Pages/Chain-Law
# 4  https://www.nps.gov/crla/planyourvisit/visitor...
#
#                                            addresses  \
# 0  [{'postalCode': '97604', 'city': 'Crater Lake'...
# 1  [{'postalCode': '97604', 'city': 'Crater Lake'...
# 2  [{'postalCode': '97604', 'city': 'Crater Lake'...
# 3  [{'postalCode': '97604', 'city': 'Crater Lake'...
# 4  [{'postalCode': '97604', 'city': 'Crater Lake'...
#
#                                                 name           lat_camp  \
# 0  Lost Creek Campground, elevation 6,000 feet (1...      42.8797493937
# 1                                  Mazama Campground  42.86862146054785
# 2  Lost Creek Campground, elevation 6,000 feet (1...      42.8797493937
# 3                                  Mazama Campground  42.86862146054785
# 4  Lost Creek Campground, elevation 6,000 feet (1...      42.8797493937
#
#              lon_camp
# 0      -122.038711217
# 1  -122.1677826463598
# 2      -122.038711217
# 3  -122.1677826463598
# 4      -122.038711217

# %%
# Output to CSV
merged_df.to_csv("statics/data/merged_df.csv", index=False,encoding="utf-8")

# %%
# Check data types
print(merged_df.dtypes)
# Out:
# parkCode          object
# fullName          object
# states            object
# latitude          object
# longitude         object
# directionsInfo    object
# operatingHours    object
# title             object
# category          object
# description       object
# url               object
# addresses         object
# name              object
# lat_camp          object
# lon_camp          object
# dtype: object

# %%
# Check data class
for col in merged_df.columns:
    print(col, type(merged_df[col][0]))
# Out:
# parkCode <class 'str'>
# fullName <class 'str'>
# states <class 'str'>
# latitude <class 'str'>
# longitude <class 'str'>
# directionsInfo <class 'str'>
# operatingHours <class 'list'>
# title <class 'str'>
# category <class 'str'>
# description <class 'str'>
# url <class 'str'>
# addresses <class 'list'>
# name <class 'str'>
# lat_camp <class 'str'>
# lon_camp <class 'str'>

# %%
# import dependency and create database engine
import sqlalchemy as sql
engine = sql.create_engine('sqlite:///data/db.sqlite')
table_name = 'Parks'

# %%
# Convert the Operating Hours column to a string representation
merged_df['operatingHours'] = merged_df['operatingHours'].apply(json.dumps)

# Convert the Addresses column to a string representation
merged_df['addresses'] = merged_df['addresses'].apply(json.dumps)

# %%
# Convert any non-UTF-8 encoded data to UTF-8
merged_df = merged_df.apply(lambda x: x.encode('utf-8').decode('utf-8', 'ignore') if isinstance(x, str) else x)
merged_df.to_sql('Parks', con=engine, if_exists='replace')
# Out:
# 2144

# %%
# Confirm data populated in database
results = engine.execute('select * from Parks').all()
results
# Out:
# [(0, 'crla', 'Crater Lake National Park', 'OR', '42.94065854', '-122.1338414', "From the west (Medford) - Take Hwy 62 to the West Entrance. Open year-round. From the south (Klamath Falls) - Take Hwy 97 north to Hwy 62 to the Sout ... (200 characters truncated) ... st to Route 230 south to Route 62 east to the park's west entrance. Travelers from Bend take Route 97 south to Route 62 to the park's south entrance.", '[{"exceptions": [{"exceptionHours": {}, "startDate": "2023-12-25", "name": "Christmas (Closed)", "endDate": "2023-12-25"}], "description": "Crater La ... (1849 characters truncated) ...  "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "North Entrance"}]', 'Road to Rim Village is Temporarily CLOSED', 'Park Closure', 'The road from Park Headquarters to Rim Village remains CLOSED due to large amounts of snow received during the most recent winter storm. There is no estimate for reopening at this time.', 'https://forecast.weather.gov/MapClick.php?lon=-122.13294982910156&lat=42.9038535772745#.ZCJgDnbMLIX', '[{"postalCode": "97604", "city": "Crater Lake", "stateCode": "OR", "line1": "Crater Lake National Park", "type": "Physical", "line3": "", "line2": "1 ... (27 characters truncated) ... Code": "97604", "city": "Crater Lake", "stateCode": "OR", "line1": "Crater Lake National Park", "type": "Mailing", "line3": "", "line2": "PO Box 7"}]', 'Lost Creek Campground, elevation 6,000 feet (1,829 meters)', '42.8797493937', '-122.038711217'),
#  (1, 'crla', 'Crater Lake National Park', 'OR', '42.94065854', '-122.1338414', "From the west (Medford) - Take Hwy 62 to the West Entrance. Open year-round. From the south (Klamath Falls) - Take Hwy 97 north to Hwy 62 to the Sout ... (200 characters truncated) ... st to Route 230 south to Route 62 east to the park's west entrance. Travelers from Bend take Route 97 south to Route 62 to the park's south entrance.", '[{"exceptions": [{"exceptionHours": {}, "startDate": "2023-12-25", "name": "Christmas (Closed)", "endDate": "2023-12-25"}], "description": "Crater La ... (1849 characters truncated) ...  "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "North Entrance"}]', 'Road to Rim Village is Temporarily CLOSED', 'Park Closure', 'The road from Park Headquarters to Rim Village remains CLOSED due to large amounts of snow received during the most recent winter storm. There is no estimate for reopening at this time.', 'https://forecast.weather.gov/MapClick.php?lon=-122.13294982910156&lat=42.9038535772745#.ZCJgDnbMLIX', '[{"postalCode": "97604", "city": "Crater Lake", "stateCode": "OR", "line1": "Crater Lake National Park", "type": "Physical", "line3": "", "line2": "1 ... (27 characters truncated) ... Code": "97604", "city": "Crater Lake", "stateCode": "OR", "line1": "Crater Lake National Park", "type": "Mailing", "line3": "", "line2": "PO Box 7"}]', 'Mazama Campground', '42.86862146054785', '-122.1677826463598'),
#  (2, 'crla', 'Crater Lake National Park', 'OR', '42.94065854', '-122.1338414', "From the west (Medford) - Take Hwy 62 to the West Entrance. Open year-round. From the south (Klamath Falls) - Take Hwy 97 north to Hwy 62 to the Sout ... (200 characters truncated) ... st to Route 230 south to Route 62 east to the park's west entrance. Travelers from Bend take Route 97 south to Route 62 to the park's south entrance.", '[{"exceptions": [{"exceptionHours": {}, "startDate": "2023-12-25", "name": "Christmas (Closed)", "endDate": "2023-12-25"}], "description": "Crater La ... (1849 characters truncated) ...  "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "North Entrance"}]', 'Crater Lake National Park is a Snow Zone', 'Caution', 'Roads are plowed, but icy and snow covered. Crater Lake National Park is a Snow Zone - chains or traction tires are required when entering the park and must be the correct size and quantity for the vehicle. All ODOT regulations apply.', 'https://tripcheck.com/Pages/Chain-Law', '[{"postalCode": "97604", "city": "Crater Lake", "stateCode": "OR", "line1": "Crater Lake National Park", "type": "Physical", "line3": "", "line2": "1 ... (27 characters truncated) ... Code": "97604", "city": "Crater Lake", "stateCode": "OR", "line1": "Crater Lake National Park", "type": "Mailing", "line3": "", "line2": "PO Box 7"}]', 'Lost Creek Campground, elevation 6,000 feet (1,829 meters)', '42.8797493937', '-122.038711217'),
#  (3, 'crla', 'Crater Lake National Park', 'OR', '42.94065854', '-122.1338414', "From the west (Medford) - Take Hwy 62 to the West Entrance. Open year-round. From the south (Klamath Falls) - Take Hwy 97 north to Hwy 62 to the Sout ... (200 characters truncated) ... st to Route 230 south to Route 62 east to the park's west entrance. Travelers from Bend take Route 97 south to Route 62 to the park's south entrance.", '[{"exceptions": [{"exceptionHours": {}, "startDate": "2023-12-25", "name": "Christmas (Closed)", "endDate": "2023-12-25"}], "description": "Crater La ... (1849 characters truncated) ...  "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "North Entrance"}]', 'Crater Lake National Park is a Snow Zone', 'Caution', 'Roads are plowed, but icy and snow covered. Crater Lake National Park is a Snow Zone - chains or traction tires are required when entering the park and must be the correct size and quantity for the vehicle. All ODOT regulations apply.', 'https://tripcheck.com/Pages/Chain-Law', '[{"postalCode": "97604", "city": "Crater Lake", "stateCode": "OR", "line1": "Crater Lake National Park", "type": "Physical", "line3": "", "line2": "1 ... (27 characters truncated) ... Code": "97604", "city": "Crater Lake", "stateCode": "OR", "line1": "Crater Lake National Park", "type": "Mailing", "line3": "", "line2": "PO Box 7"}]', 'Mazama Campground', '42.86862146054785', '-122.1677826463598'),
#  (4, 'crla', 'Crater Lake National Park', 'OR', '42.94065854', '-122.1338414', "From the west (Medford) - Take Hwy 62 to the West Entrance. Open year-round. From the south (Klamath Falls) - Take Hwy 97 north to Hwy 62 to the Sout ... (200 characters truncated) ... st to Route 230 south to Route 62 east to the park's west entrance. Travelers from Bend take Route 97 south to Route 62 to the park's south entrance.", '[{"exceptions": [{"exceptionHours": {}, "startDate": "2023-12-25", "name": "Christmas (Closed)", "endDate": "2023-12-25"}], "description": "Crater La ... (1849 characters truncated) ...  "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "North Entrance"}]', 'Steel Visitor Center is Closed for Construction', 'Information', 'The visitor center at park headquarters is currently closed for a major rehabilitation project. Restrooms are available at Rim Village and Goodbye Picnic Area.', 'https://www.nps.gov/crla/planyourvisit/visitorcenters.htm', '[{"postalCode": "97604", "city": "Crater Lake", "stateCode": "OR", "line1": "Crater Lake National Park", "type": "Physical", "line3": "", "line2": "1 ... (27 characters truncated) ... Code": "97604", "city": "Crater Lake", "stateCode": "OR", "line1": "Crater Lake National Park", "type": "Mailing", "line3": "", "line2": "PO Box 7"}]', 'Lost Creek Campground, elevation 6,000 feet (1,829 meters)', '42.8797493937', '-122.038711217'),
#  (5, 'crla', 'Crater Lake National Park', 'OR', '42.94065854', '-122.1338414', "From the west (Medford) - Take Hwy 62 to the West Entrance. Open year-round. From the south (Klamath Falls) - Take Hwy 97 north to Hwy 62 to the Sout ... (200 characters truncated) ... st to Route 230 south to Route 62 east to the park's west entrance. Travelers from Bend take Route 97 south to Route 62 to the park's south entrance.", '[{"exceptions": [{"exceptionHours": {}, "startDate": "2023-12-25", "name": "Christmas (Closed)", "endDate": "2023-12-25"}], "description": "Crater La ... (1849 characters truncated) ...  "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "North Entrance"}]', 'Steel Visitor Center is Closed for Construction', 'Information', 'The visitor center at park headquarters is currently closed for a major rehabilitation project. Restrooms are available at Rim Village and Goodbye Picnic Area.', 'https://www.nps.gov/crla/planyourvisit/visitorcenters.htm', '[{"postalCode": "97604", "city": "Crater Lake", "stateCode": "OR", "line1": "Crater Lake National Park", "type": "Physical", "line3": "", "line2": "1 ... (27 characters truncated) ... Code": "97604", "city": "Crater Lake", "stateCode": "OR", "line1": "Crater Lake National Park", "type": "Mailing", "line3": "", "line2": "PO Box 7"}]', 'Mazama Campground', '42.86862146054785', '-122.1677826463598'),
#  (6, 'crla', 'Crater Lake National Park', 'OR', '42.94065854', '-122.1338414', "From the west (Medford) - Take Hwy 62 to the West Entrance. Open year-round. From the south (Klamath Falls) - Take Hwy 97 north to Hwy 62 to the Sout ... (200 characters truncated) ... st to Route 230 south to Route 62 east to the park's west entrance. Travelers from Bend take Route 97 south to Route 62 to the park's south entrance.", '[{"exceptions": [{"exceptionHours": {}, "startDate": "2023-12-25", "name": "Christmas (Closed)", "endDate": "2023-12-25"}], "description": "Crater La ... (1849 characters truncated) ...  "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "North Entrance"}]', 'Rim Drive and North Entrance Road Closed for the Season', 'Park Closure', 'The park has closed Rim Drive, North Entrance and Pinnacles Roads for the winter season. Please be prepared for winter driving conditions.', 'https://www.nps.gov/crla/learn/news/winter-fees-and-road-closures-at-crater-lake-national-park.htm', '[{"postalCode": "97604", "city": "Crater Lake", "stateCode": "OR", "line1": "Crater Lake National Park", "type": "Physical", "line3": "", "line2": "1 ... (27 characters truncated) ... Code": "97604", "city": "Crater Lake", "stateCode": "OR", "line1": "Crater Lake National Park", "type": "Mailing", "line3": "", "line2": "PO Box 7"}]', 'Lost Creek Campground, elevation 6,000 feet (1,829 meters)', '42.8797493937', '-122.038711217'),
#  (7, 'crla', 'Crater Lake National Park', 'OR', '42.94065854', '-122.1338414', "From the west (Medford) - Take Hwy 62 to the West Entrance. Open year-round. From the south (Klamath Falls) - Take Hwy 97 north to Hwy 62 to the Sout ... (200 characters truncated) ... st to Route 230 south to Route 62 east to the park's west entrance. Travelers from Bend take Route 97 south to Route 62 to the park's south entrance.", '[{"exceptions": [{"exceptionHours": {}, "startDate": "2023-12-25", "name": "Christmas (Closed)", "endDate": "2023-12-25"}], "description": "Crater La ... (1849 characters truncated) ...  "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "North Entrance"}]', 'Rim Drive and North Entrance Road Closed for the Season', 'Park Closure', 'The park has closed Rim Drive, North Entrance and Pinnacles Roads for the winter season. Please be prepared for winter driving conditions.', 'https://www.nps.gov/crla/learn/news/winter-fees-and-road-closures-at-crater-lake-national-park.htm', '[{"postalCode": "97604", "city": "Crater Lake", "stateCode": "OR", "line1": "Crater Lake National Park", "type": "Physical", "line3": "", "line2": "1 ... (27 characters truncated) ... Code": "97604", "city": "Crater Lake", "stateCode": "OR", "line1": "Crater Lake National Park", "type": "Mailing", "line3": "", "line2": "PO Box 7"}]', 'Mazama Campground', '42.86862146054785', '-122.1677826463598'),
#  (8, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'River Mountain Loop Trail Partial Closure - MM 11.5-20.5', 'Park Closure', 'The River Mountain Loop will be closed for resurfacing and crack repair from mile marker 11.5 to approximately mile marker 20.5 from April 3 through July 30, 2023.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Boulder Beach Campground (Lake Mead)', '36.036950329698435', '-114.80191660139093'),
#  (9, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'River Mountain Loop Trail Partial Closure - MM 11.5-20.5', 'Park Closure', 'The River Mountain Loop will be closed for resurfacing and crack repair from mile marker 11.5 to approximately mile marker 20.5 from April 3 through July 30, 2023.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Boulder Beach Group Campground (Lake Mead)', '36.03752520072463', '-114.8025731005672'),
#  (10, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'River Mountain Loop Trail Partial Closure - MM 11.5-20.5', 'Park Closure', 'The River Mountain Loop will be closed for resurfacing and crack repair from mile marker 11.5 to approximately mile marker 20.5 from April 3 through July 30, 2023.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Callville Bay Campground (Lake Mead)', '36.1378088551872', '-114.72861216150869'),
#  (11, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'River Mountain Loop Trail Partial Closure - MM 11.5-20.5', 'Park Closure', 'The River Mountain Loop will be closed for resurfacing and crack repair from mile marker 11.5 to approximately mile marker 20.5 from April 3 through July 30, 2023.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Callville Bay RV Park (Lake Mead)', '36.143263', '-114.725594'),
#  (12, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'River Mountain Loop Trail Partial Closure - MM 11.5-20.5', 'Park Closure', 'The River Mountain Loop will be closed for resurfacing and crack repair from mile marker 11.5 to approximately mile marker 20.5 from April 3 through July 30, 2023.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Cottonwood Cove Campground (Lake Mohave)', '35.487755719796056', '-114.69503347257717'),
#  (13, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'River Mountain Loop Trail Partial Closure - MM 11.5-20.5', 'Park Closure', 'The River Mountain Loop will be closed for resurfacing and crack repair from mile marker 11.5 to approximately mile marker 20.5 from April 3 through July 30, 2023.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Cottonwood Cove RV Park (Lake Mead)', '35.49080255042127', '-114.68835234952485'),
#  (14, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'River Mountain Loop Trail Partial Closure - MM 11.5-20.5', 'Park Closure', 'The River Mountain Loop will be closed for resurfacing and crack repair from mile marker 11.5 to approximately mile marker 20.5 from April 3 through July 30, 2023.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Echo Bay Campground (Lake Mead)', '36.30813734081407', '-114.4368978637836'),
#  (15, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'River Mountain Loop Trail Partial Closure - MM 11.5-20.5', 'Park Closure', 'The River Mountain Loop will be closed for resurfacing and crack repair from mile marker 11.5 to approximately mile marker 20.5 from April 3 through July 30, 2023.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Echo Bay RV Park (Lake Mead)', '36.310075538623266', '-114.43199832188293'),
#  (16, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'River Mountain Loop Trail Partial Closure - MM 11.5-20.5', 'Park Closure', 'The River Mountain Loop will be closed for resurfacing and crack repair from mile marker 11.5 to approximately mile marker 20.5 from April 3 through July 30, 2023.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Katherine Landing Campground (Lake Mohave)', '35.223175690624814', '-114.55677723796998'),
#  (17, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'River Mountain Loop Trail Partial Closure - MM 11.5-20.5', 'Park Closure', 'The River Mountain Loop will be closed for resurfacing and crack repair from mile marker 11.5 to approximately mile marker 20.5 from April 3 through July 30, 2023.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Katherine Landing RV Park (Lake Mohave)', '35.22234390934542', '-114.56200692629523'),
#  (18, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'River Mountain Loop Trail Partial Closure - MM 11.5-20.5', 'Park Closure', 'The River Mountain Loop will be closed for resurfacing and crack repair from mile marker 11.5 to approximately mile marker 20.5 from April 3 through July 30, 2023.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Lake Mead RV Village (Lake Mead)', '36.03503', '-114.800453'),
#  (19, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'River Mountain Loop Trail Partial Closure - MM 11.5-20.5', 'Park Closure', 'The River Mountain Loop will be closed for resurfacing and crack repair from mile marker 11.5 to approximately mile marker 20.5 from April 3 through July 30, 2023.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Las Vegas Bay Campground (Lake Mead)', '36.12784458588996', '-114.87256967216257'),
#  (20, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'River Mountain Loop Trail Partial Closure - MM 11.5-20.5', 'Park Closure', 'The River Mountain Loop will be closed for resurfacing and crack repair from mile marker 11.5 to approximately mile marker 20.5 from April 3 through July 30, 2023.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Temple Bar Campground (Lake Mead)', '36.03031828993541', '-114.32485227007857'),
#  (21, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'River Mountain Loop Trail Partial Closure - MM 11.5-20.5', 'Park Closure', 'The River Mountain Loop will be closed for resurfacing and crack repair from mile marker 11.5 to approximately mile marker 20.5 from April 3 through July 30, 2023.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Temple Bar RV Park (Lake Mead)', '36.03413715620238', '-114.32279284224819'),
#  (22, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'River Mountain Loop Trail Partial Closure - MM 11.5-20.5', 'Park Closure', 'The River Mountain Loop will be closed for resurfacing and crack repair from mile marker 11.5 to approximately mile marker 20.5 from April 3 through July 30, 2023.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Willow Beach Campground (Lake Mohave)', '35.87336335576787', '-114.6521633431546'),
#  (23, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'River Mountain Loop Trail Partial Closure - MM 11.5-20.5', 'Park Closure', 'The River Mountain Loop will be closed for resurfacing and crack repair from mile marker 11.5 to approximately mile marker 20.5 from April 3 through July 30, 2023.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Willow Beach RV Park', '35.87336335576787', '-114.65216334315461'),
#  (24, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'Temporary Closure - Echo Bay Primitive Dirt Launch Ramp', 'Caution', 'Park facilities crews have encountered water-saturated silt that can trap vehicles at the primitive, dirt launch ramp at Echo Bay. For now, the area will be open to paddle craft only.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Boulder Beach Campground (Lake Mead)', '36.036950329698435', '-114.80191660139093'),
#  (25, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'Temporary Closure - Echo Bay Primitive Dirt Launch Ramp', 'Caution', 'Park facilities crews have encountered water-saturated silt that can trap vehicles at the primitive, dirt launch ramp at Echo Bay. For now, the area will be open to paddle craft only.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Boulder Beach Group Campground (Lake Mead)', '36.03752520072463', '-114.8025731005672'),
#  (26, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'Temporary Closure - Echo Bay Primitive Dirt Launch Ramp', 'Caution', 'Park facilities crews have encountered water-saturated silt that can trap vehicles at the primitive, dirt launch ramp at Echo Bay. For now, the area will be open to paddle craft only.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Callville Bay Campground (Lake Mead)', '36.1378088551872', '-114.72861216150869'),
#  (27, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'Temporary Closure - Echo Bay Primitive Dirt Launch Ramp', 'Caution', 'Park facilities crews have encountered water-saturated silt that can trap vehicles at the primitive, dirt launch ramp at Echo Bay. For now, the area will be open to paddle craft only.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Callville Bay RV Park (Lake Mead)', '36.143263', '-114.725594'),
#  (28, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'Temporary Closure - Echo Bay Primitive Dirt Launch Ramp', 'Caution', 'Park facilities crews have encountered water-saturated silt that can trap vehicles at the primitive, dirt launch ramp at Echo Bay. For now, the area will be open to paddle craft only.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Cottonwood Cove Campground (Lake Mohave)', '35.487755719796056', '-114.69503347257717'),
#  (29, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'Temporary Closure - Echo Bay Primitive Dirt Launch Ramp', 'Caution', 'Park facilities crews have encountered water-saturated silt that can trap vehicles at the primitive, dirt launch ramp at Echo Bay. For now, the area will be open to paddle craft only.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Cottonwood Cove RV Park (Lake Mead)', '35.49080255042127', '-114.68835234952485'),
#  (30, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'Temporary Closure - Echo Bay Primitive Dirt Launch Ramp', 'Caution', 'Park facilities crews have encountered water-saturated silt that can trap vehicles at the primitive, dirt launch ramp at Echo Bay. For now, the area will be open to paddle craft only.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Echo Bay Campground (Lake Mead)', '36.30813734081407', '-114.4368978637836'),
#  (31, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'Temporary Closure - Echo Bay Primitive Dirt Launch Ramp', 'Caution', 'Park facilities crews have encountered water-saturated silt that can trap vehicles at the primitive, dirt launch ramp at Echo Bay. For now, the area will be open to paddle craft only.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Echo Bay RV Park (Lake Mead)', '36.310075538623266', '-114.43199832188293'),
#  (32, 'lake', 'Lake Mead National Recreation Area', 'AZ,NV', '35.96622528', '-114.3469067', "By car you can drive to one of the park's many entrances. The six main entrances to Lake Mead are as follows: Northshore, Lake Mead Boulevard, Lake M ... (42 characters truncated) ... eadview. For the southern sections of the park, near Lake Mohave, there are entrance stations at Willow Beach, Katherine Landing and Cottonwood Cove.", '[{"exceptions": [], "description": "The park has implemented modifications to operations to support federal, state and local efforts to slow the spre ... (178 characters truncated) ... "All Day", "thursday": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Operating Hours"}]', 'Temporary Closure - Echo Bay Primitive Dirt Launch Ramp', 'Caution', 'Park facilities crews have encountered water-saturated silt that can trap vehicles at the primitive, dirt launch ramp at Echo Bay. For now, the area will be open to paddle craft only.', '', '[{"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "Lake Mead Visitor Center", "type": "Physical", "line3": "", "line2": "1 ... (8 characters truncated) ... ore Rd"}, {"postalCode": "89005", "city": "Boulder City", "stateCode": "NV", "line1": "601 Nevada Way", "type": "Mailing", "line3": "", "line2": ""}]', 'Katherine Landing Campground (Lake Mohave)', '35.223175690624814', '-114.55677723796998'),
# ...
#  (989, 'piro', 'Pictured Rocks National Lakeshore', 'MI', '46.56435642', '-86.31628733', "Pictured Rocks NL is located on the south shore of Lake Superior in Michigan's Upper Peninsula, between the towns of Munising (west) and Grand Marais ... (210 characters truncated) ... roviding access to spur roads that lead to scenic overlooks, trailheads, campgrounds, beaches, etc. Most park roads are closed in winter due to snow.", '[{"exceptions": [], "description": "Pictured Rocks National Lakeshore is open year-round, 24 hours a day, though most roads are closed by snow in the ... (137 characters truncated) ... ay": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Pictured Rocks National Lakeshore"}]', 'Park Entrance Fee Increase', 'Information', 'Park entrance fees will increase beginning January 1, 2023. See the park fee web page for more information.', 'https://www.nps.gov/piro/planyourvisit/fees.htm', '[{"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "1505 Sand Point Road", "type": "Physical", "line3": "", "line2": ""}, {"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "P.O. Box 40", "type": "Mailing", "line3": "", "line2": ""}]', 'Trappers Lake Individual Backpacking Sites', '46.586517', '-86.316522'),
#  (990, 'piro', 'Pictured Rocks National Lakeshore', 'MI', '46.56435642', '-86.31628733', "Pictured Rocks NL is located on the south shore of Lake Superior in Michigan's Upper Peninsula, between the towns of Munising (west) and Grand Marais ... (210 characters truncated) ... roviding access to spur roads that lead to scenic overlooks, trailheads, campgrounds, beaches, etc. Most park roads are closed in winter due to snow.", '[{"exceptions": [], "description": "Pictured Rocks National Lakeshore is open year-round, 24 hours a day, though most roads are closed by snow in the ... (137 characters truncated) ... ay": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Pictured Rocks National Lakeshore"}]', 'Park Entrance Fee Increase', 'Information', 'Park entrance fees will increase beginning January 1, 2023. See the park fee web page for more information.', 'https://www.nps.gov/piro/planyourvisit/fees.htm', '[{"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "1505 Sand Point Road", "type": "Physical", "line3": "", "line2": ""}, {"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "P.O. Box 40", "type": "Mailing", "line3": "", "line2": ""}]', 'Twelvemile Beach Campground', '46.6408', '-86.21583'),
#  (991, 'piro', 'Pictured Rocks National Lakeshore', 'MI', '46.56435642', '-86.31628733', "Pictured Rocks NL is located on the south shore of Lake Superior in Michigan's Upper Peninsula, between the towns of Munising (west) and Grand Marais ... (210 characters truncated) ... roviding access to spur roads that lead to scenic overlooks, trailheads, campgrounds, beaches, etc. Most park roads are closed in winter due to snow.", '[{"exceptions": [], "description": "Pictured Rocks National Lakeshore is open year-round, 24 hours a day, though most roads are closed by snow in the ... (137 characters truncated) ... ay": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Pictured Rocks National Lakeshore"}]', 'Other Closures', 'Park Closure', "All the park's drive-in campgrounds are closed for the season. All vault toilets in the park have been shut down, except at Sand Point and Grand Sable Visitor Center parking lot. Flush toilet at Munising Falls remains open.", '', '[{"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "1505 Sand Point Road", "type": "Physical", "line3": "", "line2": ""}, {"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "P.O. Box 40", "type": "Mailing", "line3": "", "line2": ""}]', 'Au Sable East Group Backpacking Site', '46.670375', '-86.13682'),
#  (992, 'piro', 'Pictured Rocks National Lakeshore', 'MI', '46.56435642', '-86.31628733', "Pictured Rocks NL is located on the south shore of Lake Superior in Michigan's Upper Peninsula, between the towns of Munising (west) and Grand Marais ... (210 characters truncated) ... roviding access to spur roads that lead to scenic overlooks, trailheads, campgrounds, beaches, etc. Most park roads are closed in winter due to snow.", '[{"exceptions": [], "description": "Pictured Rocks National Lakeshore is open year-round, 24 hours a day, though most roads are closed by snow in the ... (137 characters truncated) ... ay": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Pictured Rocks National Lakeshore"}]', 'Other Closures', 'Park Closure', "All the park's drive-in campgrounds are closed for the season. All vault toilets in the park have been shut down, except at Sand Point and Grand Sable Visitor Center parking lot. Flush toilet at Munising Falls remains open.", '', '[{"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "1505 Sand Point Road", "type": "Physical", "line3": "", "line2": ""}, {"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "P.O. Box 40", "type": "Mailing", "line3": "", "line2": ""}]', 'Au Sable East Individual Backpacking Sites', '46.669327', '-86.135215'),
#  (993, 'piro', 'Pictured Rocks National Lakeshore', 'MI', '46.56435642', '-86.31628733', "Pictured Rocks NL is located on the south shore of Lake Superior in Michigan's Upper Peninsula, between the towns of Munising (west) and Grand Marais ... (210 characters truncated) ... roviding access to spur roads that lead to scenic overlooks, trailheads, campgrounds, beaches, etc. Most park roads are closed in winter due to snow.", '[{"exceptions": [], "description": "Pictured Rocks National Lakeshore is open year-round, 24 hours a day, though most roads are closed by snow in the ... (137 characters truncated) ... ay": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Pictured Rocks National Lakeshore"}]', 'Other Closures', 'Park Closure', "All the park's drive-in campgrounds are closed for the season. All vault toilets in the park have been shut down, except at Sand Point and Grand Sable Visitor Center parking lot. Flush toilet at Munising Falls remains open.", '', '[{"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "1505 Sand Point Road", "type": "Physical", "line3": "", "line2": ""}, {"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "P.O. Box 40", "type": "Mailing", "line3": "", "line2": ""}]', 'Beaver Creek Individual Backpacking Sites', '46.577012', '-86.350163'),
#  (994, 'piro', 'Pictured Rocks National Lakeshore', 'MI', '46.56435642', '-86.31628733', "Pictured Rocks NL is located on the south shore of Lake Superior in Michigan's Upper Peninsula, between the towns of Munising (west) and Grand Marais ... (210 characters truncated) ... roviding access to spur roads that lead to scenic overlooks, trailheads, campgrounds, beaches, etc. Most park roads are closed in winter due to snow.", '[{"exceptions": [], "description": "Pictured Rocks National Lakeshore is open year-round, 24 hours a day, though most roads are closed by snow in the ... (137 characters truncated) ... ay": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Pictured Rocks National Lakeshore"}]', 'Other Closures', 'Park Closure', "All the park's drive-in campgrounds are closed for the season. All vault toilets in the park have been shut down, except at Sand Point and Grand Sable Visitor Center parking lot. Flush toilet at Munising Falls remains open.", '', '[{"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "1505 Sand Point Road", "type": "Physical", "line3": "", "line2": ""}, {"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "P.O. Box 40", "type": "Mailing", "line3": "", "line2": ""}]', 'Benchmark Individual Backpacking Sites', '46.647014', '-86.200461'),
#  (995, 'piro', 'Pictured Rocks National Lakeshore', 'MI', '46.56435642', '-86.31628733', "Pictured Rocks NL is located on the south shore of Lake Superior in Michigan's Upper Peninsula, between the towns of Munising (west) and Grand Marais ... (210 characters truncated) ... roviding access to spur roads that lead to scenic overlooks, trailheads, campgrounds, beaches, etc. Most park roads are closed in winter due to snow.", '[{"exceptions": [], "description": "Pictured Rocks National Lakeshore is open year-round, 24 hours a day, though most roads are closed by snow in the ... (137 characters truncated) ... ay": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Pictured Rocks National Lakeshore"}]', 'Other Closures', 'Park Closure', "All the park's drive-in campgrounds are closed for the season. All vault toilets in the park have been shut down, except at Sand Point and Grand Sable Visitor Center parking lot. Flush toilet at Munising Falls remains open.", '', '[{"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "1505 Sand Point Road", "type": "Physical", "line3": "", "line2": ""}, {"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "P.O. Box 40", "type": "Mailing", "line3": "", "line2": ""}]', 'Chapel Individual Backpacking Sites', '46.546925', '-86.440929'),
#  (996, 'piro', 'Pictured Rocks National Lakeshore', 'MI', '46.56435642', '-86.31628733', "Pictured Rocks NL is located on the south shore of Lake Superior in Michigan's Upper Peninsula, between the towns of Munising (west) and Grand Marais ... (210 characters truncated) ... roviding access to spur roads that lead to scenic overlooks, trailheads, campgrounds, beaches, etc. Most park roads are closed in winter due to snow.", '[{"exceptions": [], "description": "Pictured Rocks National Lakeshore is open year-round, 24 hours a day, though most roads are closed by snow in the ... (137 characters truncated) ... ay": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Pictured Rocks National Lakeshore"}]', 'Other Closures', 'Park Closure', "All the park's drive-in campgrounds are closed for the season. All vault toilets in the park have been shut down, except at Sand Point and Grand Sable Visitor Center parking lot. Flush toilet at Munising Falls remains open.", '', '[{"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "1505 Sand Point Road", "type": "Physical", "line3": "", "line2": ""}, {"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "P.O. Box 40", "type": "Mailing", "line3": "", "line2": ""}]', 'Cliffs Group Backpacking Site', '46.48567', '-86.556577'),
#  (997, 'piro', 'Pictured Rocks National Lakeshore', 'MI', '46.56435642', '-86.31628733', "Pictured Rocks NL is located on the south shore of Lake Superior in Michigan's Upper Peninsula, between the towns of Munising (west) and Grand Marais ... (210 characters truncated) ... roviding access to spur roads that lead to scenic overlooks, trailheads, campgrounds, beaches, etc. Most park roads are closed in winter due to snow.", '[{"exceptions": [], "description": "Pictured Rocks National Lakeshore is open year-round, 24 hours a day, though most roads are closed by snow in the ... (137 characters truncated) ... ay": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Pictured Rocks National Lakeshore"}]', 'Other Closures', 'Park Closure', "All the park's drive-in campgrounds are closed for the season. All vault toilets in the park have been shut down, except at Sand Point and Grand Sable Visitor Center parking lot. Flush toilet at Munising Falls remains open.", '', '[{"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "1505 Sand Point Road", "type": "Physical", "line3": "", "line2": ""}, {"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "P.O. Box 40", "type": "Mailing", "line3": "", "line2": ""}]', 'Cliffs Individual Backpacking Sites', '46.473431', '-86.570456'),
#  (998, 'piro', 'Pictured Rocks National Lakeshore', 'MI', '46.56435642', '-86.31628733', "Pictured Rocks NL is located on the south shore of Lake Superior in Michigan's Upper Peninsula, between the towns of Munising (west) and Grand Marais ... (210 characters truncated) ... roviding access to spur roads that lead to scenic overlooks, trailheads, campgrounds, beaches, etc. Most park roads are closed in winter due to snow.", '[{"exceptions": [], "description": "Pictured Rocks National Lakeshore is open year-round, 24 hours a day, though most roads are closed by snow in the ... (137 characters truncated) ... ay": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Pictured Rocks National Lakeshore"}]', 'Other Closures', 'Park Closure', "All the park's drive-in campgrounds are closed for the season. All vault toilets in the park have been shut down, except at Sand Point and Grand Sable Visitor Center parking lot. Flush toilet at Munising Falls remains open.", '', '[{"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "1505 Sand Point Road", "type": "Physical", "line3": "", "line2": ""}, {"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "P.O. Box 40", "type": "Mailing", "line3": "", "line2": ""}]', 'Coves Group Backpacking Site', '46.56088', '-86.395902'),
#  (999, 'piro', 'Pictured Rocks National Lakeshore', 'MI', '46.56435642', '-86.31628733', "Pictured Rocks NL is located on the south shore of Lake Superior in Michigan's Upper Peninsula, between the towns of Munising (west) and Grand Marais ... (210 characters truncated) ... roviding access to spur roads that lead to scenic overlooks, trailheads, campgrounds, beaches, etc. Most park roads are closed in winter due to snow.", '[{"exceptions": [], "description": "Pictured Rocks National Lakeshore is open year-round, 24 hours a day, though most roads are closed by snow in the ... (137 characters truncated) ... ay": "All Day", "sunday": "All Day", "tuesday": "All Day", "friday": "All Day", "saturday": "All Day"}, "name": "Pictured Rocks National Lakeshore"}]', 'Other Closures', 'Park Closure', "All the park's drive-in campgrounds are closed for the season. All vault toilets in the park have been shut down, except at Sand Point and Grand Sable Visitor Center parking lot. Flush toilet at Munising Falls remains open.", '', '[{"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "1505 Sand Point Road", "type": "Physical", "line3": "", "line2": ""}, {"postalCode": "49862", "city": "Munising", "stateCode": "MI", "line1": "P.O. Box 40", "type": "Mailing", "line3": "", "line2": ""}]', 'Coves Individual Backpacking Sites', '46.568171', '-86.372254'),
#  ...]

# %%
# Check data types in database
for col in results[0]:
    print(type(col))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
